# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\49074251803\appdata\roaming\python\python313\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\49074251803\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.3.3)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    -------------------------------- ------- 7.1/8.7 MB 35.0 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 34.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 14.7 MB/s eta 0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.2-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    --- ------------------------------------ 3.1/38.5 MB 23.5 MB/s eta 0:00:02
#    --- ------------------------------------ 3.1/38.5 MB 23.5 MB/s eta 0:00:02
#    ------- -------------------------------- 7.1/38.5 MB 11.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.0/38.5 MB 12.1 MB/s eta 0:00:03
#    -------------- ------------------------- 13.6/38.5 MB 13.3 MB/s eta 0:00:02
#    -------------- ------------------------- 13.6/38.5 MB 13.3 MB/s eta 0:00:02
#    -------------- ------------------------- 13.6/38.5 MB 13.3 MB/s eta 0:00:02
#    --------------- ------------------------ 14.7/38.5 MB 10.0 MB/s eta 0:00:03
#    --------------- ------------------------ 14.7/38.5 MB 10.0 MB/s eta 0:00:03
#    --------------- ------------------------ 14.9/38.5 MB 7.2 MB/s eta 0:00:04
#    -------------------- ------------------- 19.9/38.5 MB 9.1 MB/s eta 0:00:03
#    -------------------- ------------------- 19.9/38.5 MB 9.1 MB/s eta 0:00:03
#    --------------------- ------------------ 20.7/38.5 MB 7.7 MB/s eta 0:00:03
#    ------------------------ --------------- 23.6/38.5 MB 8.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.6/38.5 MB 9.2 MB/s eta 0:00:02
#    ------------------------------ --------- 29.4/38.5 MB 9.4 MB/s eta 0:00:01
#    ------------------------------ --------- 29.4/38.5 MB 9.4 MB/s eta 0:00:01
#    ------------------------------ --------- 29.4/38.5 MB 9.4 MB/s eta 0:00:01
#    ------------------------------- -------- 30.4/38.5 MB 7.8 MB/s eta 0:00:02
#    -------------------------------------- - 36.7/38.5 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 8.7 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 scipy-1.16.2 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# criando o conjunto de dados
notas = np.array([8,6,5,9,4,3,7,2,1,5,6,9,8])
classes = np.array(['bom','ruim','ruim','bom','pessimo','pessimo','bom','pessimo','pessimo',
                    'ruim','ruim','bom','bom'])

# %%
# Dividindo a base de dados em treino e teste
notas_treino,notas_teste,classes_treino,classes_teste=train_test_split(notas.reshape(-1,1),
                                                                       classes.reshape(-1,1),
                                                                       test_size=0.2, # 20% dos dados para treino 
                                                                       random_state=42 ) # permite a reprodutibilidade dos testes

# %%
# Criação do modelo de Machine Learning Árvore de decisão
modelo = DecisionTreeClassifier() # cria o modelo
modelo.fit(notas_treino,classes_treino) # treinamento do modelo
# Out:
# DecisionTreeClassifier()

# %%
# Teste do modelo
print(modelo.predict(notas_teste)) 
print(notas_teste)
# Out:
# ['bom' 'ruim' 'bom']
# [[9]
#  [5]
#  [8]]

# %%
modelo.predict(np.array([4]).reshape(-1,1))
# Out:
# array(['pessimo'], dtype='<U7')
