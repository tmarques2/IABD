# %%
pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/60.9 kB 871.5 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 359.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 15.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.2/11.3 MB 15.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.5/11.3 MB 19.7 MB/s eta 0:00:01
#    --------------- ------------------------ 4.4/11.3 MB 25.5 MB/s eta 0:00:01
#    -------------------------- ------------- 7.4/11.3 MB 33.8 MB/s eta 0:00:01
# ...

# %%
print("olá")
# Out:
# olá

# %%
import pandas as pd
